# %% [markdown]
# # Introduction to Deep Learning
# ## Logistic Regression
# Logistic Regression is a fundamental supervised learning algorithm used for binary classification tasks. Despite its name, it's used for classification, not regression. Logistic Regression models the probability that a given input belongs to a particular class.

# %% [markdown]
# ### Implementation Steps
# 1. Data Pre-processing
# 2. Parameter Initialization
# 3. Forward Propagation:
# 4. Cost Calculation
# 5. Backward Propagation
# 6. Parameter Update
# 7. Model Evaluation

# %% [markdown]
# Let's import libraries we've already learnt and will use

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Data Pre-Processing
# The dataset contains information that may be used for diagnosing or predicting the presence of heart disease in individuals. It comprises various clinical and demographic features that are commonly considered in cardiovascular health assessment. Understanding and analyzing these features can aid in developing predictive models or understanding the factors associated with heart disease.
# The first 13 fields are
# - Age
# - Sex
# - Chest Pain Type (cp)
# - Resting Blood Pressure (trestbps)
# - Serum Cholesterol Level (chol)
# - Fasting Blood Sugar (fbs)
# - Resting Electrocardiographic Results (restecg)
# - Maximum Heart Rate Achieved (thalach)
# - Exercise-Induced Angina (exang)
# - ST Depression Induced by Exercise Relative to Rest (oldpeak)
# - Slope of the Peak Exercise ST Segment (slope)
# - Number of Major Vessels Colored by Fluoroscopy (ca)
# - Thalassemia (thal)
#
# And the 14th field is 'target' and is either 0 or 1. The "target" field refers to the presence of heart disease in the patient. It is integer valued 0 = no disease and 1 = disease.

# %% [markdown]
# First, we import data from the csv file provided

# %%
dataset_raw = np.genfromtxt("./dataset/heart.csv", dtype="str", delimiter=",")
print(dataset_raw.shape)
# Out:
# (1026, 14)

# %%
print(dataset_raw)
# Out:
# [['age' 'sex' 'cp' ... 'ca' 'thal' 'target']
#  ['52' '1' '0' ... '2' '3' '0']
#  ['53' '1' '0' ... '0' '3' '0']
#  ...
#  ['47' '1' '0' ... '1' '2' '0']
#  ['50' '0' '0' ... '0' '2' '1']
#  ['54' '1' '0' ... '1' '3' '0']]

# %% [markdown]
# This dataset have headers that we don't need for logistic regression model. That is there for us to understand what the values denote
# We seperate the headers

# %%
headers = dataset_raw[0, :]
print(headers)
# Out:
# ['age' 'sex' 'cp' 'trestbps' 'chol' 'fbs' 'restecg' 'thalach' 'exang'
#  'oldpeak' 'slope' 'ca' 'thal' 'target']

# %% [markdown]
# And now we get rest of the numerical data and cast them as `float` data type instead of `string`

# %%
dataset = dataset_raw[1:, :]
dataset = dataset.astype(float)
print(dataset)
# Out:
# [[52.  1.  0. ...  2.  3.  0.]
#  [53.  1.  0. ...  0.  3.  0.]
#  [70.  1.  0. ...  0.  3.  0.]
#  ...
#  [47.  1.  0. ...  1.  2.  0.]
#  [50.  0.  0. ...  0.  2.  1.]
#  [54.  1.  0. ...  1.  3.  0.]]

# %% [markdown]
# In this dataset, the first 13 columns represent the features, while the 14th column indicates whether the individual has the disease or not based on those features. Here we seperate the dataset into X (feature vector) and Y (output vector).

# %%
X = dataset[:, :13]
Y = dataset[:, 13]
print(X.shape)
print(Y.shape)
# Out:
# (1025, 13)
# (1025,)

# %% [markdown]
# Shape of X here is $(m, n_x)$, but we want it to have $shape = (n_x, m)$

# %%
X = X.T
print(X.shape)
print(Y.shape)
# Out:
# (13, 1025)
# (1025,)

# %% [markdown]
# #### Looks good
# Finally, we have 1025 examples of 13 features and 1 output
# From the notation you have studied till now
# $$
# \begin{align*}
# n_x &= 13 \\
# n_y &= 1 \\
# m &= 1025
# \end{align*}
# $$
# Now we can proceed to making our logistic regression model and train our model
# But, we have one problem to deal with. How would we know if our model is doing good and if it is, how good is it?
# That is why from the 1025 examples we have, we'll keep some data aside and use it to test our model's prediction
# Let's keep 80% of the data for training and 20% of the data for testing our model

# %%
# get index to split data in 80:20 ratio
index = int(0.8 * X.shape[1])

# split the data
X_train = X[:, :index]
X_test = X[:, index:]

Y_train = Y[:index]
Y_test = Y[index:]

# %% [markdown]
# Let's print shapes for our dataset

# %%
print("X_train shape", X_train.shape)
print("Y_train shape", Y_train.shape)
print("Number of training examples =", Y_train.shape[0])
print("-"*40)
print("X_test shape", X_test.shape)
print("Y_test shape", Y_test.shape)
print("Number of testing examples =", Y_test.shape[0])
# Out:
# X_train shape (13, 820)
# Y_train shape (820,)
# Number of training examples = 820
# ----------------------------------------
# X_test shape (13, 205)
# Y_test shape (205,)
# Number of testing examples = 205

# %% [markdown]
# ## Logistic Regression
# #### Forward Propagation
# $$
# Z = W^T X + b  \\
# A = sigmoid(X) \\
# $$
# #### Calculate Cost
# $$
# J = -\frac{1}{m}\sum_{i=1}^{m}y^{(i)}\log(a^{(i)})+(1-y^{(i)})\log(1-a^{(i)})
# $$
# #### Backward Propagation
# $$ \partial W = \frac{\partial J}{\partial W} = \frac{1}{m}X(A-Y)^T\tag{7}$$
# $$ \partial b = \frac{\partial J}{\partial b} = \frac{1}{m} \sum_{i=1}^m (a^{(i)}-y^{(i)})\tag{8}$$
# #### Parameter Updation
# $$ W = W - \alpha \text{ } \partial W $$
# $$ b = b - \alpha \text{ } \partial b $$

# %% [markdown]
# ### 2. Initializing parameters
# **Assignment**: Complete the function for parameter initialization in the cell below.

# %%
def init_params(num_features):
  """
    This function creates a vector of zeros of shape (dim, 1) for w and initializes b to 0.

    Returns:
    W -- initialized vector of shape (num_features, 1)
    b -- initialized scalar (corresponds to the bias)
  """

  W = np.zeros((num_features, 1))
  b = 0

  return W, b

# %% [markdown]
# #### **Helper Function**: Sigmoid
# **Assignment**: Complete the function for calculating sigmoid in the cell below.

# %%
def sigmoid(x):
  """
    Compute the sigmoid of x

    Return:
    s -- sigmoid(x)
  """
  
  s = 1 / (1 + np.exp(-x))

  return s

# %% [markdown]
# ### 3. Forward Propagation
# $$
# Z = W^T X + b  \\
# A = sigmoid(X) \\
# $$
# **Assignment**: Complete the function implementing forward propagation in the cell below.

# %%
def forward_prop(W, b, X):
  """
    Compute forward propagation

    Return:
    A -- activation
  """

  # forward propagation
  Z = np.dot(W.T, X) + b
  A = sigmoid(Z)
  
  return A

# %% [markdown]
# ### 4. Calculate Cost
# $$
# J = -\frac{1}{m}\sum_{i=1}^{m}y^{(i)}\log(a^{(i)})+(1-y^{(i)})\log(1-a^{(i)})
# $$
# **Assignment**: Complete the function to calculate cost in the cell below.

# %%
def calculate_loss(A, Y):
  """
    Calculate cross entropy loss between calculated values (A) and actual values (Y)

    Return:
    cost -- cost calculated
  """

  # get number of examples
  m = Y.shape[0]

  # calculate cost
  cost = (-1 / m) * np.sum(Y * np.log(A) + (1 - Y) * np.log(1 - A))

  # this will remove any useless dimensions from cost
  # not doing this might give us an array instead of a single value
  cost = np.squeeze(cost)

  return cost

# %% [markdown]
# ### 5. Backward Propagation
# $$ \partial W = \frac{\partial J}{\partial W} = \frac{1}{m}X(A-Y)^T\tag{7}$$
# $$ \partial b = \frac{\partial J}{\partial b} = \frac{1}{m} \sum_{i=1}^m (a^{(i)}-y^{(i)})\tag{8}$$
# **Assignment**: Complete the function to compute gradients in the cell below.

# %%
def backward_prop(A, X, Y):
  """
    Calculate gradients dW and db

    Return:
    dw -- gradient of the loss with respect to w, thus same shape as w
    db -- gradient of the loss with respect to b, thus same shape as b
  """

  # get number of examples
  m = Y.shape[0]

  # calculate gradients
  dW = (1/m) * np.dot(X, (A - Y).T)
  db = (1/m) * np.sum(A-Y)

  return dW, db

# %% [markdown]
# ### 6. Parameter Updation
# $$ W = W - \alpha \text{ } \partial W $$
# $$ b = b - \alpha \text{ } \partial b $$
# **Assignment**: Complete the function to update parameters in the cell below.

# %%
def update_params(W, b, dW, db, learning_rate):
  """
    Update params W and b from their gradients

    Return:
    W -- updated W
    b -- updated b
  """

  W = W - learning_rate * dW
  b = b - learning_rate * db

  return W, b

# %% [markdown]
# As our model's forward propagation return value calculated from sigmoid function, it lies between 0 and 1
# We can say output should be 1 when A > 0.5 and 0 when A < 0.5
# Let's implement a function that will do this for us in vectorized way
# ### Predict

# %%
def predict(W, b, X):
  A = forward_prop(W, b, X)
  Y_pred = (A>=0.5)*1.0
  return Y_pred

# %% [markdown]
# ### Let's compile all these function to implement training loop for our model
# You don't need to write any math here, just put all the functions you've written above in the right sequence

# %%
def train(X, Y, num_iterations=200001, learning_rate=0.0001, print_cost=True):
  # initialize parameters
  W, b = init_params(X.shape[0])

  # let's keep track of our cost to see how our model
  # reduces cost after every few iteration
  costs = []

  for i in range(num_iterations):

    # forward propagation
    A = forward_prop(W, b, X)

    # calculate cost
    cost = calculate_loss(A, Y)

    # backward propagation
    dW, db = backward_prop(A, X, Y)

    # parameter updation
    W, b = update_params(W, b, dW, db, learning_rate)

    # store cost after every few iterations
    if i%100 == 0:
      costs.append(cost)

    # print cost after every few iterations
    if print_cost and i%100 == 0:
      print(f"Cost after {i+1} iteration : {cost}")
    
  return W, b, costs

# %% [markdown]
# ### Let the model train

# %%
W, b, costs = train(X_train, Y_train)
# Out:
# Cost after 1 iteration : 0.6931471805599453
# Cost after 101 iteration : 0.7723673062806204
# Cost after 201 iteration : 0.6739935941292493
# Cost after 301 iteration : 0.641782495209394
# Cost after 401 iteration : 0.6285874648436628
# Cost after 501 iteration : 0.622941525571305
# Cost after 601 iteration : 0.6201697454114334
# Cost after 80601 iteration : 0.3755677261735074
# Cost after 80701 iteration : 0.3755139518691383
# Cost after 80801 iteration : 0.3754602922205148
# Cost after 80901 iteration : 0.3754067468716012
# Cost after 81001 iteration : 0.37535331546777545
# Cost after 81101 iteration : 0.3752999976558227
# Cost after 81201 iteration : 0.37524679308392855
# Cost after 81301 iteration : 0.375193701401672
# Cost after 81401 iteration : 0.3751407222600195
# Cost after 81501 iteration : 0.3750878553113175
# Cost after 81601 iteration : 0.37503510020928676
# Cost after 81701 iteration : 0.37498245660901486
# Cost after 81801 iteration : 0.37492992416695037
# Cost after 81901 iteration : 0.37487750254089625
# Cost after 82001 iteration : 0.37482519139000336
# Cost after 82101 iteration : 0.37477299037476375
# Cost after 82201 iteration : 0.3747208991570051
# Cost after 82301 iteration : 0.37466891739988345
# Cost after 82401 iteration : 0.37461704476787755
# Cost after 82501 iteration : 0.37456528092678243
# Cost after 82601 iteration : 0.37451362554370315
# Cost after 82701 iteration : 0.37446207828704825
# Cost after 82801 iteration : 0.3744106388265245
# Cost after 82901 iteration : 0.37435930683312996
# Cost after 83001 iteration : 0.374308081979148
# Cost after 83101 iteration : 0.3742569639381418
# Cost after 83201 iteration : 0.3742059523849476
# Cost after 83301 iteration : 0.3741550469956692
# Cost after 83401 iteration : 0.37410424744767184
# Cost after 83501 iteration : 0.3740535534195763
# Cost after 83601 iteration : 0.3740029645912531
# Cost after 83701 iteration : 0.3739524806438162
# Cost after 83801 iteration : 0.3739021012596179
# Cost after 83901 iteration : 0.3738518261222425
# Cost after 84001 iteration : 0.37380165491650075
# Cost after 84101 iteration : 0.37375158732842395
# Cost after 84201 iteration : 0.3737016230452588
# Cost after 84301 iteration : 0.3736517617554605
# Cost after 84401 iteration : 0.3736020031486888
# Cost after 84501 iteration : 0.3735523469158008
# Cost after 84601 iteration : 0.37350279274884673
# Cost after 84701 iteration : 0.37345334034106303
# Cost after 84801 iteration : 0.3734039893868683
# Cost after 84901 iteration : 0.37335473958185655
# Cost after 85001 iteration : 0.37330559062279245
# Cost after 85101 iteration : 0.3732565422076058
# Cost after 85201 iteration : 0.37320759403538584
# Cost after 85301 iteration : 0.3731587458063763
# Cost after 85401 iteration : 0.3731099972219698
# Cost after 85501 iteration : 0.37306134798470236
# Cost after 85601 iteration : 0.3730127977982489
# Cost after 85701 iteration : 0.37296434636741693
# Cost after 85801 iteration : 0.37291599339814197
# Cost after 85901 iteration : 0.3728677385974821
# Cost after 86001 iteration : 0.3728195816736134
# Cost after 86101 iteration : 0.3727715223358237
# Cost after 86201 iteration : 0.3727235602945085
# Cost after 86301 iteration : 0.372675695261165
# Cost after 86401 iteration : 0.3726279269483882
# Cost after 86501 iteration : 0.37258025506986453
# Cost after 86601 iteration : 0.3725326793403679
# Cost after 86701 iteration : 0.3724851994757539
# Cost after 86801 iteration : 0.37243781519295566
# Cost after 86901 iteration : 0.37239052620997837
# Cost after 87001 iteration : 0.37234333224589444
# Cost after 87101 iteration : 0.3722962330208388
# Cost after 87201 iteration : 0.3722492282560039
# Cost after 93901 iteration : 0.36930139195428513
# Cost after 94001 iteration : 0.3692602099227017
# Cost after 94101 iteration : 0.36921910541516006
# Cost after 94201 iteration : 0.3691780782162299
# Cost after 94301 iteration : 0.3691371281112517
# Cost after 94401 iteration : 0.36909625488633396
# Cost after 94501 iteration : 0.3690554583283494
# Cost after 94601 iteration : 0.3690147382249318
# Cost after 94701 iteration : 0.36897409436447276
# Cost after 94801 iteration : 0.3689335265361184
# Cost after 94901 iteration : 0.3688930345297662
# Cost after 95001 iteration : 0.36885261813606157
# Cost after 95101 iteration : 0.36881227714639486
# Cost after 95201 iteration : 0.3687720113528981
# Cost after 95301 iteration : 0.3687318205484415
# Cost after 95401 iteration : 0.36869170452663086
# Cost after 95501 iteration : 0.36865166308180386
# Cost after 95601 iteration : 0.3686116960090271
# Cost after 95701 iteration : 0.3685718031040934
# Cost after 95801 iteration : 0.36853198416351807
# Cost after 95901 iteration : 0.3684922389845361
# Cost after 96001 iteration : 0.368452567365099
# Cost after 96101 iteration : 0.3684129691038721
# Cost after 96201 iteration : 0.36837344400023087
# Cost after 96301 iteration : 0.3683339918542584
# Cost after 96401 iteration : 0.3682946124667422
# Cost after 96501 iteration : 0.3682553056391711
# Cost after 96601 iteration : 0.36821607117373256
# Cost after 96701 iteration : 0.3681769088733094
# Cost after 96801 iteration : 0.36813781854147704
# Cost after 96901 iteration : 0.3680987999825004
# Cost after 97001 iteration : 0.36805985300133115
# Cost after 97101 iteration : 0.3680209774036047
# Cost after 97201 iteration : 0.367982172995637
# Cost after 97301 iteration : 0.3679434395844226
# Cost after 97401 iteration : 0.3679047769776306
# Cost after 97501 iteration : 0.3678661849836026
# Cost after 97601 iteration : 0.36782766341134937
# Cost after 97701 iteration : 0.3677892120705487
# Cost after 97801 iteration : 0.36775083077154147
# Cost after 97901 iteration : 0.36771251932533044
# Cost after 98001 iteration : 0.3676742775435755
# Cost after 98101 iteration : 0.36763610523859297
# Cost after 98201 iteration : 0.36759800222335104
# Cost after 98301 iteration : 0.36755996831146814
# Cost after 98401 iteration : 0.36752200331720997
# Cost after 98501 iteration : 0.3674841070554865
# Cost after 98601 iteration : 0.36744627934184954
# Cost after 98701 iteration : 0.3674085199924899
# Cost after 98801 iteration : 0.367370828824235
# Cost after 98901 iteration : 0.36733320565454586
# Cost after 99001 iteration : 0.36729565030151434
# Cost after 99101 iteration : 0.36725816258386107
# Cost after 99201 iteration : 0.3672207423209325
# Cost after 99301 iteration : 0.36718338933269795
# Cost after 99401 iteration : 0.36714610343974763
# Cost after 99501 iteration : 0.36710888446328976
# ...
# Cost after 167701 iteration : 0.35137386050373043
# Cost after 167801 iteration : 0.3513595197167924
# Cost after 167901 iteration : 0.35134519468268743
# Cost after 168001 iteration : 0.35133088537493096
# Cost after 168101 iteration : 0.3513165917670987
# Cost after 168201 iteration : 0.35130231383282606
# Cost after 168301 iteration : 0.3512880515458082
# Cost after 168401 iteration : 0.35127380487979987
# Cost after 168501 iteration : 0.35125957380861494
# Cost after 168601 iteration : 0.35124535830612696
# Cost after 175301 iteration : 0.3503270684643535
# Cost after 175401 iteration : 0.3503138534276197
# Cost after 175501 iteration : 0.35030065229090335
# Cost after 175601 iteration : 0.35028746503184155
# Cost after 175701 iteration : 0.35027429162812
# Cost after 175801 iteration : 0.35026113205747317
# Cost after 175901 iteration : 0.3502479862976841
# Cost after 176001 iteration : 0.35023485432658363
# Cost after 176101 iteration : 0.3502217361220515
# Cost after 176201 iteration : 0.35020863166201505
# Cost after 176301 iteration : 0.3501955409244498
# Cost after 176401 iteration : 0.350182463887379
# Cost after 176501 iteration : 0.3501694005288737
# Cost after 176601 iteration : 0.35015635082705215
# Cost after 176701 iteration : 0.35014331476008076
# Cost after 176801 iteration : 0.35013029230617243
# Cost after 176901 iteration : 0.35011728344358783
# Cost after 177001 iteration : 0.35010428815063444
# Cost after 177101 iteration : 0.35009130640566677
# Cost after 177201 iteration : 0.3500783381870859
# Cost after 177301 iteration : 0.3500653834733399
# Cost after 177401 iteration : 0.35005244224292326
# Cost after 177501 iteration : 0.35003951447437703
# Cost after 177601 iteration : 0.3500266001462883
# Cost after 177701 iteration : 0.3500136992372905
# Cost after 177801 iteration : 0.3500008117260631
# Cost after 177901 iteration : 0.3499879375913317
# Cost after 178001 iteration : 0.3499750768118674
# Cost after 178101 iteration : 0.349962229366487
# Cost after 178201 iteration : 0.34994939523405344
# Cost after 178301 iteration : 0.34993657439347436
# Cost after 178401 iteration : 0.349923766823703
# Cost after 178501 iteration : 0.34991097250373804
# Cost after 178601 iteration : 0.34989819141262307
# Cost after 178701 iteration : 0.3498854235294465
# Cost after 178801 iteration : 0.34987266883334184
# Cost after 178901 iteration : 0.3498599273034873
# Cost after 179001 iteration : 0.34984719891910554
# Cost after 179101 iteration : 0.3498344836594638
# Cost after 179201 iteration : 0.34982178150387383
# Cost after 179301 iteration : 0.34980909243169134
# Cost after 179401 iteration : 0.34979641642231657
# Cost after 179501 iteration : 0.34978375345519347
# Cost after 179601 iteration : 0.34977110350981
# Cost after 179701 iteration : 0.34975846656569787
# Cost after 179801 iteration : 0.3497458426024326
# Cost after 179901 iteration : 0.34973323159963315
# Cost after 180001 iteration : 0.3497206335369621
# Cost after 180101 iteration : 0.34970804839412506
# Cost after 180201 iteration : 0.34969547615087104
# Cost after 180301 iteration : 0.3496829167869923
# Cost after 180401 iteration : 0.34967037028232373
# Cost after 180501 iteration : 0.34965783661674343
# Cost after 180601 iteration : 0.34964531577017205
# Cost after 180701 iteration : 0.349632807722573
# Cost after 180801 iteration : 0.3496203124539523
# Cost after 180901 iteration : 0.34960782994435824
# Cost after 181001 iteration : 0.3495953601738814
# Cost after 181101 iteration : 0.34958290312265483
# Cost after 181201 iteration : 0.34957045877085335
# Cost after 181301 iteration : 0.349558027098694
# Cost after 181401 iteration : 0.3495456080864355
# Cost after 181501 iteration : 0.3495332017143786
# Cost after 181601 iteration : 0.34952080796286555
# Cost after 181701 iteration : 0.3495084268122799
# Cost after 181801 iteration : 0.3494960582430472
# Cost after 181901 iteration : 0.3494837022356338
# Cost after 188601 iteration : 0.34868347866133925
# Cost after 188701 iteration : 0.3486719331936757
# Cost after 188801 iteration : 0.3486603990339639
# Cost after 188901 iteration : 0.34864887616531287
# Cost after 189001 iteration : 0.348637364570866
# Cost after 189101 iteration : 0.3486258642338008
# Cost after 189201 iteration : 0.34861437513732935
# Cost after 189301 iteration : 0.34860289726469756
# Cost after 189401 iteration : 0.3485914305991858
# Cost after 189501 iteration : 0.3485799751241078
# Cost after 189601 iteration : 0.34856853082281203
# Cost after 189701 iteration : 0.34855709767868004
# Cost after 189801 iteration : 0.3485456756751275
# Cost after 189901 iteration : 0.3485342647956035
# Cost after 190001 iteration : 0.3485228650235911
# Cost after 190101 iteration : 0.3485114763426061
# Cost after 190201 iteration : 0.3485000987361985
# Cost after 190301 iteration : 0.3484887321879511
# Cost after 190401 iteration : 0.3484773766814801
# Cost after 190501 iteration : 0.34846603220043476
# Cost after 190601 iteration : 0.3484546987284975
# Cost after 190701 iteration : 0.3484433762493835
# Cost after 190801 iteration : 0.3484320647468412
# Cost after 190901 iteration : 0.34842076420465146
# Cost after 191001 iteration : 0.34840947460662797
# Cost after 191101 iteration : 0.3483981959366174
# Cost after 191201 iteration : 0.3483869281784985
# Cost after 191301 iteration : 0.34837567131618263
# Cost after 191401 iteration : 0.3483644253336138
# Cost after 191501 iteration : 0.348353190214768
# Cost after 191601 iteration : 0.3483419659436537
# Cost after 191701 iteration : 0.3483307525043114
# Cost after 191801 iteration : 0.34831954988081376
# Cost after 191901 iteration : 0.34830835805726534
# Cost after 192001 iteration : 0.3482971770178027
# Cost after 192101 iteration : 0.3482860067465941
# Cost after 192201 iteration : 0.34827484722783975
# Cost after 192301 iteration : 0.3482636984457713
# Cost after 192401 iteration : 0.34825256038465235
# Cost after 192501 iteration : 0.3482414330287776
# Cost after 192601 iteration : 0.3482303163624735
# Cost after 192701 iteration : 0.3482192103700977
# Cost after 192801 iteration : 0.3482081150360391
# Cost after 192901 iteration : 0.348197030344718
# Cost after 193001 iteration : 0.34818595628058574
# Cost after 193101 iteration : 0.34817489282812464
# Cost after 193201 iteration : 0.34816383997184797
# Cost after 193301 iteration : 0.34815279769630014
# Cost after 193401 iteration : 0.348141765986056
# Cost after 193501 iteration : 0.34813074482572154
# Cost after 193601 iteration : 0.34811973419993303
# Cost after 193701 iteration : 0.34810873409335774
# Cost after 193801 iteration : 0.34809774449069303
# Cost after 193901 iteration : 0.3480867653766671
# Cost after 194001 iteration : 0.3480757967360382
# Cost after 194101 iteration : 0.348064838553595
# Cost after 194201 iteration : 0.3480538908141565
# Cost after 194301 iteration : 0.34804295350257153
# Cost after 194401 iteration : 0.34803202660371935
# Cost after 194501 iteration : 0.3480211101025088
# Cost after 194601 iteration : 0.3480102039838791
# Cost after 194701 iteration : 0.34799930823279906
# Cost after 194801 iteration : 0.3479884228342671
# Cost after 194901 iteration : 0.3479775477733117
# Cost after 195001 iteration : 0.3479666830349906
# Cost after 195101 iteration : 0.34795582860439145
# Cost after 195201 iteration : 0.34794498446663097
# Cost after 195301 iteration : 0.34793415060685573
# Cost after 195401 iteration : 0.3479233270102413
# Cost after 195501 iteration : 0.3479125136619926
# Cost after 195601 iteration : 0.3479017105473438
# Cost after 195701 iteration : 0.34789091765155816
# Cost after 195801 iteration : 0.3478801349599278
# Cost after 195901 iteration : 0.34786936245777417
# Cost after 196001 iteration : 0.34785860013044734
# Cost after 196101 iteration : 0.34784784796332635
# Cost after 196201 iteration : 0.3478371059418188
# Cost after 196301 iteration : 0.3478263740513613
# Cost after 196401 iteration : 0.34781565227741884
# Cost after 196501 iteration : 0.347804940605485
# Cost after 196601 iteration : 0.34779423902108186
# Cost after 196701 iteration : 0.3477835475097599
# Cost after 196801 iteration : 0.3477728660570981
# Cost after 196901 iteration : 0.34776219464870345
# Cost after 197001 iteration : 0.3477515332702112
# Cost after 197101 iteration : 0.34774088190728486
# Cost after 197201 iteration : 0.34773024054561597
# Cost after 197301 iteration : 0.347719609170924
# Cost after 197401 iteration : 0.34770898776895626
# Cost after 197501 iteration : 0.3476983763254882
# Cost after 197601 iteration : 0.34768777482632285
# Cost after 197701 iteration : 0.34767718325729086
# Cost after 197801 iteration : 0.347666601604251
# Cost after 197901 iteration : 0.347656029853089
# Cost after 198001 iteration : 0.3476454679897186
# Cost after 198101 iteration : 0.34763491600008073
# Cost after 198201 iteration : 0.3476243738701439
# Cost after 198301 iteration : 0.3476138415859038
# Cost after 198401 iteration : 0.3476033191333834
# Cost after 198501 iteration : 0.3475928064986329
# Cost after 198601 iteration : 0.3475823036677295
# Cost after 198701 iteration : 0.3475718106267776
# Cost after 198801 iteration : 0.3475613273619087
# Cost after 198901 iteration : 0.3475508538592809
# Cost after 199001 iteration : 0.3475403901050794
# Cost after 199101 iteration : 0.3475299360855161
# Cost after 199201 iteration : 0.3475194917868296
# Cost after 199301 iteration : 0.34750905719528546
# Cost after 199401 iteration : 0.3474986322971753
# Cost after 199501 iteration : 0.3474882170788178
# Cost after 199601 iteration : 0.3474778115265579
# Cost after 199701 iteration : 0.34746741562676675
# Cost after 199801 iteration : 0.3474570293658422
# Cost after 199901 iteration : 0.34744665273020825
# Cost after 200001 iteration : 0.34743628570631513

# %% [markdown]
# Let's plot costs to see how our model was converging

# %%
plt.plot(costs)
plt.show()

# %% [markdown]
# ### 7. Model Evaluation
# Let's check accuracy on train and test sets

# %%
print("Train accuracy: {} %".format(100 - np.mean(np.abs(predict(W, b, X_train) - Y_train)) * 100))
print("Test accuracy: {} %".format(100 - np.mean(np.abs(predict(W, b, X_test) - Y_test)) * 100))
# Out:
# Train accuracy: 86.70731707317073 %
# Test accuracy: 80.0 %

# %% [markdown]
# Increasing the number of iterations can improve training accuracy, but there's a risk of overfitting. Overfitting occurs when the model learns to fit the training data too closely, capturing noise or irrelevant patterns that don't generalize well to unseen data. In such cases, while the training accuracy continues to increase, the test accuracy may plateau or even decrease.
#
# To address overfitting, techniques like regularization and model complexity reduction are employed. Additionally, the transition to deep neural networks offers more sophisticated methods for improving accuracies, even in the presence of overfitting.
